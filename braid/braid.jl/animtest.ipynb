# %%
using Plots

# %%
@gif for i in 1:50
    plot(sin, 0, i * 2pi / 10)
end
# Out:
# ┌ Info: Saved animation to /home/cadaverous/Projects/lss-braid/xbraid/braid/braid.jl/tmp.gif
# └ @ Plots /home/cadaverous/.julia/packages/Plots/9Q9pN/src/animation.jl:156
# Plots.AnimatedGif("/home/cadaverous/Projects/lss-braid/xbraid/braid/braid.jl/tmp.gif")
